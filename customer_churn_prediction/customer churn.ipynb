# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"C:\Users\acer\Desktop\nest_internship\customer_churn_prediction\churn.csv")

# %%
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 194   2146-EGVDT    Male              0     Yes        Yes      59
# 5904  9402-CXWPL  Female              0      No         No      70
# 3190  3745-HRPHI    Male              0     Yes        Yes      66
# 4724  5073-RZGBK  Female              0     Yes        Yes      50
# 6433  2346-LOCWC  Female              0     Yes        Yes      58
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 194           Yes                No              No  No internet service  ...
# 5904          Yes               Yes     Fiber optic                   No  ...
# 3190           No  No phone service             DSL                   No  ...
# 4724          Yes               Yes             DSL                  Yes  ...
# 6433          Yes                No              No  No internet service  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 194   No internet service  No internet service  No internet service
# 5904                   No                   No                  Yes
# 3190                  Yes                  Yes                  Yes
# 4724                  Yes                  Yes                   No
# 6433  No internet service  No internet service  No internet service
#
#           StreamingMovies  Contract PaperlessBilling  \
# 194   No internet service  Two year               No
# 5904                  Yes  One year               No
# 3190                  Yes  Two year               No
# 4724                  Yes  One year              Yes
# 6433  No internet service  Two year               No
#
#                   PaymentMethod MonthlyCharges  TotalCharges Churn
# 194     Credit card (automatic)          19.30        1192.7    No
# 5904           Electronic check          98.90        6838.6    No
# 3190  Bank transfer (automatic)          54.65          3632    No
# 4724  Bank transfer (automatic)          80.05        4042.2    No
# 6433    Credit card (automatic)          20.50        1191.4    No
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
#  17  PaymentMethod     7043 non-null   str
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   str
#  20  Churn             7043 non-null   str
# dtypes: float64(1), int64(2), str(18)
# memory usage: 1.1 MB

# %%
df.drop('customerID',axis='columns',inplace=True)

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
colors = ["#34eb6b" , "#0099ff"]

plt.figure(figsize = (20, 6))

counts = df["gender"].value_counts()
explode = (0, 0.1)

counts.plot(kind = 'pie', fontsize = 12, colors = colors, explode = explode, autopct = '%.1f%%')
plt.title('Males Vs Females')
plt.xlabel('Gender', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.ylabel('Counts', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.legend(labels = counts.index, loc = "best")
plt.show()

# %%
df['gender'] = df['gender'].map({'Male': 0, 'Female': 1})

# %%
df['Partner'].value_counts()
# Out:
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64

# %%
colors = ["#34eb6b" , "#0099ff"]

plt.figure(figsize = (20, 6))

counts = df["Partner"].value_counts()
explode = (0, 0.1)

counts.plot(kind = 'pie', fontsize = 12, colors = colors, explode = explode, autopct = '%.1f%%')
plt.title('Yes Vs No')
plt.xlabel('Status', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.ylabel('Count', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.legend(labels = counts.index, loc = "best")
plt.show()

# %%
df['Partner'] = df['Partner'].map({'No': 0, 'Yes': 1})

# %%
df['Dependents'].value_counts()
# Out:
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64

# %%
colors = ["#34eb6b" , "#0099ff"]

plt.figure(figsize = (20, 6))

ax = df["Dependents"].value_counts().plot(kind = 'bar', color = colors[:2], rot = 0)
ax.set_xticklabels(('Yes', 'No'))

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
    ax.tick_params(axis = 'both', labelsize = 15)

plt.xlabel('Status', weight = "bold", color = "#D71313", fontsize = 14)
plt.ylabel('Count', weight = "bold", color = "#D71313", fontsize = 14);

# %%
df['Dependents'] = df['Dependents'].map({'No': 0, 'Yes': 1})

# %%
df['PhoneService'].value_counts()
# Out:
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64

# %%
colors = ["#34eb6b" , "#0099ff"]

plt.figure(figsize = (20, 6))

ax = df["PhoneService"].value_counts().plot(kind = 'bar', color = colors[:2], rot = 0)
ax.set_xticklabels(('Yes', 'No'))

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
    ax.tick_params(axis = 'both', labelsize = 15)

plt.xlabel('Status', weight = "bold", color = "#D71313", fontsize = 14)
plt.ylabel('Count', weight = "bold", color = "#D71313", fontsize = 14);

# %%
df['PhoneService'] = df['PhoneService'].map({'No': 0, 'Yes': 1})

# %%
df['MultipleLines'].value_counts()
# Out:
# MultipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64

# %%
colors = ["#2B299B" , "#3B74C9" , "#85DFE3"]

plt.figure(figsize = (20, 6))

counts = df["MultipleLines"].value_counts()
explode = (0, 0.1  , 0.1)

counts.plot(kind = 'pie', fontsize = 12, colors = colors, explode = explode, autopct = '%.1f%%')
plt.title('Status')
plt.xlabel('Status', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.ylabel('Count', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.legend(labels = counts.index, loc = "best")
plt.show()

# %%
mapping_dict = {'No phone service': 0, 'No': 0, 'Yes': 1}

df['MultipleLines'] = df['MultipleLines'].map(mapping_dict)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df.InternetService = le.fit_transform(df.InternetService)

# %%
df.Contract = le.fit_transform(df.Contract)

# %%
df.PaymentMethod = le.fit_transform(df.PaymentMethod)

# %%
df.sample(4)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 1844       0              0        1           0      59             1
# 3447       0              0        0           0      39             1
# 5406       0              0        1           1      71             1
# 1397       1              0        0           0       4             1
#
#       MultipleLines  InternetService OnlineSecurity OnlineBackup  \
# 1844              0                0            Yes          Yes
# 3447              1                1             No          Yes
# 5406              1                1            Yes           No
# 1397              0                1             No           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 1844              Yes          No         Yes              No         1
# 3447               No          No          No              No         1
# 5406               No          No         Yes             Yes         2
# 1397              Yes          No          No             Yes         0
#
#      PaperlessBilling  PaymentMethod  MonthlyCharges TotalCharges Churn
# 1844               No              1           66.40       3958.2    No
# 3447               No              1           81.40      3213.75    No
# 5406              Yes              2           97.20       6910.3    No
# 1397              Yes              1           82.85        319.6    No

# %%
df.replace('No internet service','No',inplace=True)
df.replace('No phone service','No',inplace=True)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          1              0        1           0       1             0
# 1          0              0        0           0      34             1
# 2          0              0        0           0       2             1
# 3          0              0        0           0      45             0
# 4          1              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       0              0        1           1      24             1
# 7039       1              0        1           1      72             1
# 7040       1              0        1           1      11             0
# 7041       0              1        1           0       4             1
# 7042       0              0        0           0      66             1
#
#       MultipleLines  InternetService OnlineSecurity OnlineBackup  \
# 0                 0                0             No          Yes
# 1                 0                0            Yes           No
# 2                 0                0            Yes          Yes
# 3                 0                0            Yes           No
# 4                 0                1             No           No
# ...             ...              ...            ...          ...
# 7038              1                0            Yes           No
# 7039              1                1             No          Yes
# 7040              0                0            Yes           No
# 7041              1                1             No           No
# 7042              0                1            Yes           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 0                  No          No          No              No         0
# 1                 Yes          No          No              No         1
# 2                  No          No          No              No         0
# 3                 Yes         Yes          No              No         1
# 4                  No          No          No              No         0
# ...               ...         ...         ...             ...       ...
# 7038              Yes         Yes         Yes             Yes         1
# 7039              Yes          No         Yes             Yes         1
# 7040               No          No          No              No         0
# 7041               No          No          No              No         0
# 7042              Yes         Yes         Yes             Yes         2
#
#      PaperlessBilling  PaymentMethod  MonthlyCharges TotalCharges Churn
# 0                 Yes              2           29.85        29.85    No
# 1                  No              3           56.95       1889.5    No
# 2                 Yes              3           53.85       108.15   Yes
# 3                  No              0           42.30      1840.75    No
# 4                 Yes              2           70.70       151.65   Yes
# ...               ...            ...             ...          ...   ...
# 7038              Yes              3           84.80       1990.5    No
# 7039              Yes              1          103.20       7362.9    No
# 7040              Yes              2           29.60       346.45    No
# 7041              Yes              3           74.40        306.6   Yes
# 7042              Yes              0          105.65       6844.5    No
#
# [7043 rows x 20 columns]

# %%
yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
                  'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
for col in yes_no_columns:
    df[col].replace({'Yes': 1,'No': 0},inplace=True)

# %%
pd.to_numeric(df.TotalCharges,errors='coerce').isnull().sum()
# Out:
# np.int64(11)

# %%
df[pd.to_numeric(df.TotalCharges,errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 488        1              0        1           1       0             0
# 753        0              0        0           1       0             1
# 936        1              0        1           1       0             1
# 1082       0              0        1           1       0             1
# 1340       1              0        1           1       0             0
# 3331       0              0        1           1       0             1
# 3826       0              0        1           1       0             1
# 4380       1              0        1           1       0             1
# 5218       0              0        1           1       0             1
# 6670       1              0        1           1       0             1
# 6754       0              0        0           1       0             1
#
#       MultipleLines  InternetService OnlineSecurity OnlineBackup  \
# 488               0                0            Yes           No
# 753               0                2             No           No
# 936               0                0            Yes          Yes
# 1082              1                2             No           No
# 1340              0                0            Yes          Yes
# 3331              0                2             No           No
# 3826              1                2             No           No
# 4380              0                2             No           No
# 5218              0                2             No           No
# 6670              1                0             No          Yes
# 6754              1                0            Yes          Yes
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 488               Yes         Yes         Yes              No         2
# 753                No          No          No              No         2
# 936               Yes          No         Yes             Yes         2
# 1082               No          No          No              No         2
# 1340              Yes         Yes         Yes              No         2
# 3331               No          No          No              No         2
# 3826               No          No          No              No         2
# 4380               No          No          No              No         2
# 5218               No          No          No              No         1
# 6670              Yes         Yes         Yes              No         2
# 6754               No         Yes          No              No         2
#
#      PaperlessBilling  PaymentMethod  MonthlyCharges TotalCharges Churn
# 488               Yes              0           52.55                 No
# 753                No              3           20.25                 No
# 936                No              3           80.85                 No
# 1082               No              3           25.75                 No
# 1340               No              1           56.05                 No
# 3331               No              3           19.85                 No
# 3826               No              3           25.35                 No
# 4380               No              3           20.00                 No
# 5218              Yes              3           19.70                 No
# 6670               No              3           73.35                 No
# 6754              Yes              0           61.90                 No

# %%
df.shape
# Out:
# (7043, 20)

# %%
df = df[df.TotalCharges!=' ']
df.shape
# Out:
# (7032, 20)

# %%
cols_to_scale = ['tenure','MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])

# %%
df[cols_to_scale ].sample(5)
# Out:
#         tenure  MonthlyCharges  TotalCharges
# 5279  0.971831        0.068657      0.204402
# 4282  0.718310        0.825871      0.609543
# 6368  0.014085        0.753731      0.018798
# 3041  0.000000        0.314925      0.003589
# 35    1.000000        0.812438      0.834630

# %%
def summary(df):
    summary_df = pd.DataFrame(df.dtypes, columns=['dtypes'])
    summary_df['missing#'] = df.isna().sum()
    summary_df['missing%'] = (df.isna().sum())/len(df)
    summary_df['unique'] = df.nunique().values
    summary_df['count'] = df.count().values
    return summary_df

summary(df).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T
col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_17247_level0_row11" class="row_heading level0 row11" >TechSupport</th>
#       <td id="T_17247_row11_col0" class="data row11 col0" >str</td>
#       <td id="T_17247_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_17247_row11_col2" class="data row11 col2" >0.000000</td>
#       <td id="T_17247_row11_col3" class="data row11 col3" >2</td>
#       <td id="T_17247_row11_col4" class="data row11 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_17247_level0_row12" class="row_heading level0 row12" >StreamingTV</th>
#       <td id="T_17247_row12_col0" class="data row12 col0" >str</td>
#       <td id="T_17247_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_17247_row12_col2" class="data row12 col2" >0.000000</td>
#       <td id="T_17247_row12_

# %%
X = df.drop('Churn',axis='columns')
y = df['Churn']

# %%
X.sample(3)
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 3889       0              0        0           0  0.169014             1
# 1872       1              0        1           1  0.563380             1
# 2235       1              0        1           1  0.563380             1
#
#       MultipleLines  InternetService OnlineSecurity OnlineBackup  \
# 3889              0                2             No           No
# 1872              0                2             No           No
# 2235              1                0            Yes          Yes
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 3889               No          No          No              No         1
# 1872               No          No          No              No         2
# 2235              Yes          No         Yes              No         1
#
#      PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges
# 3889               No              1        0.010448      0.027793
# 1872               No              0        0.014428      0.090636
# 2235              Yes              1        0.598010      0.368382

# %%
y.sample(3)
# Out:
# 4773    Yes
# 239      No
# 395      No
# Name: Churn, dtype: str

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train.shape
# Out:
# (5625, 19)

# %%
X_test.shape
# Out:
# (1407, 19)

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in C:\Users\acer\Desktop\nest_internship\venv\Lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\acer\Desktop\nest_internship\venv\Lib\site-packages (from scikit-learn) (2.5.0)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\acer\Desktop\nest_internship\venv\Lib\site-packages (from scikit-learn) (1.18.0)
# Requirement already satisfied: joblib>=1.4.0 in C:\Users\acer\Desktop\nest_internship\venv\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\acer\Desktop\nest_internship\venv\Lib\site-packages (from scikit-learn) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\acer\Desktop\nest_internship\venv\Lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
print("Train Accuracy:", model.score(X_train, y_train))
print("Test Accuracy:", model.score(X_test, y_test))
# Out:
# Train Accuracy: 0.8220444444444445
# Test Accuracy: 0.7860696517412935

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.83      0.90      0.86      1033
#          Yes       0.63      0.48      0.55       374
#
#     accuracy                           0.79      1407
#    macro avg       0.73      0.69      0.70      1407
# weighted avg       0.77      0.79      0.78      1407

# %%
report = classification_report(y_test, y_pred, output_dict=True)
rep = pd.DataFrame(report).transpose()

plt.figure(figsize=(10, 6))
sns.heatmap(rep.iloc[:-1, :-1], annot=True, cmap='Blues')
plt.title('Classification Report')
plt.show()

# %%
from sklearn.metrics import classification_report

report = classification_report(
    y_test,
    y_pred,
    output_dict=True
)

# %%
print(report.keys())
# Out:
# dict_keys(['No', 'Yes', 'accuracy', 'macro avg', 'weighted avg'])

# %%
classes = ['No', 'Yes']

precision = [report['No']['precision'], report['Yes']['precision']]
recall = [report['No']['recall'], report['Yes']['recall']]
f1_score = [report['No']['f1-score'], report['Yes']['f1-score']]

# %%
plt.figure(figsize=(12, 6))
barWidth = 0.25
r1 = range(len(classes))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]

plt.bar(r1, precision, width=barWidth, edgecolor='grey', label='Precision')
plt.bar(r2, recall, width=barWidth, edgecolor='grey', label='Recall')
plt.bar(r3, f1_score, width=barWidth, edgecolor='grey', label='F1-score')

plt.xlabel('Class')
plt.xticks([r + barWidth for r in range(len(classes))], classes)
plt.legend()
plt.title("Classification Report Metrics")
plt.show()

# %%
from sklearn.neural_network import MLPClassifier

model = MLPClassifier(
    hidden_layer_sizes=(15, 15),
    activation='relu',
    solver='adam',
    max_iter=1000,
    random_state=42
)

model.fit(X_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(15, 15), max_iter=1000, random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.83      0.90      0.86      1033
#          Yes       0.63      0.48      0.55       374
#
#     accuracy                           0.79      1407
#    macro avg       0.73      0.69      0.70      1407
# weighted avg       0.77      0.79      0.78      1407

# %%
cm = confusion_matrix(y_test, y_pred)

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (5625, 19)
# (1407, 19)

# %%
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, confusion_matrix

# Features and target
X = df.drop('Churn', axis=1)
y = df['Churn']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=5
)

# Model
model = MLPClassifier(
    hidden_layer_sizes=(15, 15),
    activation='relu',
    solver='adam',
    max_iter=1000,
    random_state=42
)

# Train
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# Accuracy
print("Train Accuracy:", model.score(X_train, y_train))
print("Test Accuracy:", model.score(X_test, y_test))

# Classification Report
print(classification_report(y_test, y_pred))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# Train Accuracy: 0.8232888888888888
# Test Accuracy: 0.7825159914712153
#               precision    recall  f1-score   support
#
#           No       0.82      0.88      0.85       999
#          Yes       0.65      0.54      0.59       408
#
#     accuracy                           0.78      1407
#    macro avg       0.74      0.71      0.72      1407
# weighted avg       0.77      0.78      0.78      1407
#
# [[881 118]
#  [188 220]]

# %%
import joblib

# Save trained model
joblib.dump(model, 'customer_churn_model.pkl')

print("Model saved successfully!")
# Out:
# Model saved successfully!
